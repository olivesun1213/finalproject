# %%
import pandas as pd

# %%
ksi=pd.read_csv("Data/ksi_cleaned.csv")
ksi.head(10)
# Out:
#    ACCNUM                    DATE  TIME  HOUR       STREET1        STREET2  \
# 0  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 1  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 2  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 3  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 4  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 5  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 6  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 7  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 8  909646  2006/01/01 05:00:00+00   315     3  DANFORTH AVE  WEST LYNN AVE
# 9  909646  2006/01/01 05:00:00+00   315     3  DANFORTH AVE  WEST LYNN AVE
#
#        ROAD_CLASS   LATITUDE  LONGITUDE      LOCCOORD  ... TRUCK  \
# 0  Major Arterial  43.699595 -79.318797  Intersection  ...    No
# ...

# %%
# Remove non-fatal injuries of fatal accidents from the dataframe
new_ksi = ksi.loc[((ksi.ACCLASS == "Fatal") & (ksi.INJURY == "Fatal")) | (ksi.ACCLASS == "Non-Fatal Injury")]
new_ksi.head(10)
# Out:
#    ACCNUM                    DATE  TIME  HOUR       STREET1        STREET2  \
# 0  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 1  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 2  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 3  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 4  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 5  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 6  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 7  893184  2006/01/01 05:00:00+00   236     2  WOODBINE AVE    O CONNOR DR
# 8  909646  2006/01/01 05:00:00+00   315     3  DANFORTH AVE  WEST LYNN AVE
# 9  909646  2006/01/01 05:00:00+00   315     3  DANFORTH AVE  WEST LYNN AVE
#
#        ROAD_CLASS   LATITUDE  LONGITUDE      LOCCOORD  ... TRUCK  \
# 0  Major Arterial  43.699595 -79.318797  Intersection  ...    No
# ...

# %%
# Keep one record for each fatal or non-fatal accident
ksi_by_accident = new_ksi.drop_duplicates('ACCNUM')
ksi_by_accident.head(10)
# Out:
#     ACCNUM                    DATE  TIME  HOUR        STREET1         STREET2  \
# 0   893184  2006/01/01 05:00:00+00   236     2   WOODBINE AVE     O CONNOR DR
# 8   909646  2006/01/01 05:00:00+00   315     3   DANFORTH AVE   WEST LYNN AVE
# 13  884090  2006/01/02 05:00:00+00   705     7    BATHURST ST     DUNDAS ST W
# 15  885782  2006/01/04 05:00:00+00  1940    19    DUFFERIN ST      SYLVAN AVE
# 17  882079  2006/01/06 05:00:00+00  2210    22   DON MILLS RD   LEITH HILL RD
# 19  882024  2006/01/07 05:00:00+00  2325    23  STEELES AVE E   NINTH LINE ST
# 22  887568  2006/01/08 05:00:00+00  1507    15  PARLIAMENT ST      FRONT ST E
# 31  882497  2006/01/08 05:00:00+00  1828    18  ISLINGTON AVE     GOLFDOWN DR
# 34  882174  2006/01/09 05:00:00+00  1435    14     KENNEDY RD   GLAMORGAN AVE
# 35  886039  2006/01/09 05:00:00+00  1820    18    FINCH AVE E  MIDDLEFIELD RD
#
#         ROAD_CLASS   LATITUDE  LONGITUDE      LOCCOORD  ... TRUCK  \
# ...

# %%
ksi_by_accident.to_csv("Data/ksi_by_accident.csv",index=False)
